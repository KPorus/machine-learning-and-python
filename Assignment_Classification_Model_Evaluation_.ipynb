# %% [markdown]
# <a href="https://colab.research.google.com/github/KPorus/machine-learning-and-python/blob/main/Assignment_Classification_Model_Evaluation_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Heart Failure Prediction Assignment

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df=pd.read_csv("heart failure.csv")
df.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# ...

# %%
df.shape
# Out:
# (299, 13)

# %%
df.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %% [markdown]
# ## Objective
# The goal of this assignment is to analyze the **heart failure clinical records** dataset and build a machine learning model to predict the occurrence of a **death event** in patients with heart failure. You will perform exploratory data analysis (EDA), visualize trends, and apply classification models to predict the target variable.
#
# ## Dataset Overview
#
# The dataset consists of 13 variables, each representing clinical features and demographic information of heart failure patients:
#
# 1. **age**: Age of the patient (years)
# 2. **anaemia**: Whether the patient has anaemia (0: no, 1: yes)
# 3. **creatinine_phosphokinase**: Level of the CPK enzyme in the blood (mcg/L)
# 4. **diabetes**: Whether the patient has diabetes (0: no, 1: yes)
# 5. **ejection_fraction**: Percentage of blood leaving the heart with each contraction (%)
# 6. **high_blood_pressure**: Whether the patient has high blood pressure (0: no, 1: yes)
# 7. **platelets**: Platelets in the blood (kiloplatelets/mL)
# 8. **serum_creatinine**: Level of serum creatinine in the blood (mg/dL)
# 9. **serum_sodium**: Level of serum sodium in the blood (mEq/L)
# 10. **sex**: Gender of the patient (1: male, 0: female)
# 11. **smoking**: Whether the patient smokes (0: no, 1: yes)
# 12. **time**: Follow-up period (days)
# 13. **DEATH_EVENT**: Whether the patient died during the follow-up period (0: no, 1: yes) [Target Variable]
#
# ## Instructions
#
# ### 1. Data Exploration (EDA)
# - **Task 1**: Load the dataset using pandas and display the first few rows.
# - **Task 2**: Check for missing values and clean the data if necessary.
# - **Task 3**: Generate summary statistics for the numerical columns.
# - **Task 4**: Visualize the distribution of the target variable (`DEATH_EVENT`).
# - **Task 5**: Plot histograms or box plots for continuous variables like `age`, `creatinine_phosphokinase`, `ejection_fraction`, `serum_creatinine`, etc.
#
# ### 2. Data Visualization
# - **Task 6**: Create a correlation matrix heatmap to understand the relationships between the features.
# - **Task 7**: Create count plots or bar charts for categorical variables like `anaemia`, `diabetes`, `high_blood_pressure`, `sex`, and `smoking`.
# - **Task 8**: Create scatter plots or pair plots for continuous variables like `age` vs `ejection_fraction`, `serum_creatinine`, etc., colored by `DEATH_EVENT`.
#
# ### 3. Model Building
# - **Task 9**: Split the dataset into features (`X`) and the target variable (`y = DEATH_EVENT`).
# - **Task 10**: Perform train-test splitting (70% training, 30% testing) using `train_test_split` from sklearn.
# - **Task 11**: Standardize the continuous features using `StandardScaler`.
#
# ### 4. Model Training and Evaluation
# - **Task 12**: Train a Logistic Regression model and evaluate it using accuracy, precision, recall, and F1-score.
# - **Task 13**: Train a K-Nearest Neighbors (KNN) model and evaluate its performance.
# - **Task 14**: Train a Decision Tree Classifier and compare its performance with other models.
#
# ### 5. Cross Validation
# - **Task 15**: Perform K-Fold Cross-Validation (with 5 folds) on the Logistic Regression model to evaluate its performance.
# - **Task 16**: Perform Stratified K-Fold Cross-Validation to ensure class balance during cross-validation.
#
# ### 6. Model Improvement
# - **Task 17**: Use Grid Search or Randomized Search to tune the hyperparameters of the KNN and Decision Tree models.
# - **Task 18**: Plot the ROC curves and calculate the AUC for all models to compare their performance visually.
#
# ### 7. Conclusion
# - **Task 19**: Summarize your findings and explain which model performed best and why. Consider which features were most important for predicting the death event.
# - **Task 20**: Suggest potential improvements or next steps for the analysis.
#
# ---
#
# ## Submission Instructions:
# - Submit your notebook file to github with the completed analysis.
# - Ensure that the notebook is well-documented with explanations for each step.
# - Include visualizations and comments on the results of each model.
# - Submit github link only

# %%
sns.countplot(data=df,x="DEATH_EVENT")
# Out:
# <Axes: xlabel='DEATH_EVENT', ylabel='count'>

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
categorical_columns = ['anaemia', 'diabetes', 'high_blood_pressure', 'sex', 'smoking']
for col in categorical_columns:
    sns.countplot(x=col, data=df)
    plt.title(f'Distribution of {col}')
    plt.show()

# %%
sns.pairplot(df[['age', 'ejection_fraction', 'serum_creatinine', 'serum_sodium', 'DEATH_EVENT']], hue='DEATH_EVENT')
plt.show()

# %%
categorical_columns = ['age', 'ejection_fraction', 'serum_creatinine','serum_sodium']
for col in categorical_columns:
    sns.distplot(df[col])
    plt.title(f'Distribution of {col}')
    plt.show()
# Out:
# <ipython-input-43-d2c62717d757>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col])
# <ipython-input-43-d2c62717d757>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col])
# <ipython-input-43-d2c62717d757>:3: UserWarning:
#
# ...

# %%
categorical_columns = ['age', 'ejection_fraction', 'serum_creatinine','serum_sodium']
for col in categorical_columns:
    sns.boxplot(df[col])
    plt.title(f'Distribution of {col}')
    plt.show()

# %%
x =df.drop('DEATH_EVENT',axis=1)
y=df['DEATH_EVENT']

# %% [markdown]
# #z-score outlier treatment

# %% [markdown]
# ##Age column

# %%
print(f"age mean:{x['age'].mean()}")
print(f"age std:{x['age'].std()}")
print(f"age min:{x['age'].min()}")
print(f"age max:{x['age'].max()}")
# Out:
# age mean:60.83389297658862
# age std:11.894809074044478
# age min:40.0
# age max:95.0

# %%
print(f"upper limit:{x['age'].mean()+3*x['age'].std()}")
print(f"lower limit:{x['age'].mean()-3*x['age'].std()}")
# Out:
# upper limit:96.51832019872205
# lower limit:25.149465754455186

# %% [markdown]
# ##ejection_fraction

# %%
mean_val = x['ejection_fraction'].mean()
std_val = x['ejection_fraction'].std()
min_val = x['ejection_fraction'].min()
max_val = x['ejection_fraction'].max()

print(f"Ejection Mean: {mean_val}")
print(f"Ejection Std: {std_val}")
print(f"Ejection Min: {min_val}")
print(f"Ejection Max: {max_val}")
# Out:
# Ejection Mean: 38.08361204013378
# Ejection Std: 11.834840741039173
# Ejection Min: 14
# Ejection Max: 80

# %%
upper_limit = mean_val + 3 * std_val
lower_limit = mean_val - 3 * std_val

print(f"Upper Limit: {upper_limit}")
print(f"Lower Limit: {lower_limit}")
# Out:
# Upper Limit: 73.5881342632513
# Lower Limit: 2.5790898170162606

# %%
x1 = x[(x['ejection_fraction'] < lower_limit) | (x['ejection_fraction'] > upper_limit)]
x1
# Out:
#      age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 64  45.0        0                       582         0                 80
#
#     high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 64                    0  263358.03              1.18           137    0
#
#     smoking  time
# 64        0    63

# %%
x['ejection_fraction'] = np.where(x['ejection_fraction'] > upper_limit, upper_limit, x['ejection_fraction'])
x
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0               20.0
# 1    55.0        0                      7861         0               38.0
# 2    65.0        0                       146         0               20.0
# 3    50.0        1                       111         0               20.0
# 4    65.0        1                       160         1               20.0
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1               38.0
# 295  55.0        0                      1820         0               38.0
# 296  45.0        0                      2060         1               60.0
# 297  45.0        0                      2413         0               38.0
# 298  50.0        0                       196         0               45.0
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
sns.boxplot(x['ejection_fraction'])
# Out:
# <Axes: ylabel='ejection_fraction'>

# %% [markdown]
# ##serum_creatinine

# %%
x['serum_creatinine'].describe()
# Out:
# count    299.000000
# mean       1.234515
# std        0.440098
# min        0.500000
# 25%        0.900000
# 50%        1.100000
# 75%        1.400000
# max        2.150000
# Name: serum_creatinine, dtype: float64

# %%
upper_limit = x['serum_creatinine'].quantile(0.75) + 1.5 * (x['serum_creatinine'].quantile(0.75) - x['serum_creatinine'].quantile(0.25))
lower_limit = x['serum_creatinine'].quantile(0.25) - 1.5 * (x['serum_creatinine'].quantile(0.75) - x['serum_creatinine'].quantile(0.25))
print(f"Upper Limit: {upper_limit}")
print(f"Lower Limit: {lower_limit}")
# Out:
# Upper Limit: 2.1499999999999995
# Lower Limit: 0.15000000000000024

# %%
new_df = x[(x['serum_creatinine'] < lower_limit) | (x['serum_creatinine'] > upper_limit)]
new_df.shape
# Out:
# (0, 12)

# %%
x['serum_creatinine'] = np.where(x['serum_creatinine'] > upper_limit, upper_limit, x['serum_creatinine'])
x
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0               20.0
# 1    55.0        0                      7861         0               38.0
# 2    65.0        0                       146         0               20.0
# 3    50.0        1                       111         0               20.0
# 4    65.0        1                       160         1               20.0
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1               38.0
# 295  55.0        0                      1820         0               38.0
# 296  45.0        0                      2060         1               60.0
# 297  45.0        0                      2413         0               38.0
# 298  50.0        0                       196         0               45.0
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
sns.boxplot(x['serum_creatinine'])
# Out:
# <Axes: ylabel='serum_creatinine'>

# %% [markdown]
# ##serum_sodium

# %%
x['serum_sodium'].describe()
# Out:
# count    299.000000
# mean     136.625418
# std        4.412477
# min      113.000000
# 25%      134.000000
# 50%      137.000000
# 75%      140.000000
# max      148.000000
# Name: serum_sodium, dtype: float64

# %%
upper_limit = x['serum_sodium'].quantile(0.75) + 1.5 * (x['serum_sodium'].quantile(0.75) - x['serum_sodium'].quantile(0.25))
lower_limit = x['serum_sodium'].quantile(0.25) - 1.5 * (x['serum_sodium'].quantile(0.75) - x['serum_sodium'].quantile(0.25))
print(f"Upper Limit: {upper_limit}")
print(f"Lower Limit: {lower_limit}")
# Out:
# Upper Limit: 149.0
# Lower Limit: 125.0

# %%
new_df = x[(x['serum_sodium'] < lower_limit) | (x['serum_sodium'] > upper_limit)]
new_df
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 4    65.0        1                       160         1               20.0
# 19   48.0        1                       582         1               55.0
# 126  46.0        0                       168         1               17.0
# 199  60.0        0                      1211         1               35.0
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 4                      0  327000.00              2.15           116    0
# 19                     0   87000.00              1.90           121    0
# 126                    1  271000.00              2.10           124    0
# 199                    0  263358.03              1.80           113    1
#
#      smoking  time
# 4          0     8
# 19         0    15
# 126        0   100
# 199        1   186

# %%
x['serum_sodium'] = np.where(x['serum_sodium'] > upper_limit, upper_limit, np.where(x['serum_sodium'] < lower_limit, lower_limit, x['serum_sodium']))
x
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0               20.0
# 1    55.0        0                      7861         0               38.0
# 2    65.0        0                       146         0               20.0
# 3    50.0        1                       111         0               20.0
# 4    65.0        1                       160         1               20.0
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1               38.0
# 295  55.0        0                      1820         0               38.0
# 296  45.0        0                      2060         1               60.0
# 297  45.0        0                      2413         0               38.0
# 298  50.0        0                       196         0               45.0
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
sns.boxplot(x['serum_sodium'])
# Out:
# <Axes: ylabel='serum_sodium'>

# %% [markdown]
# # Data split for finding feature importance

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=1)

# %% [markdown]
# ##scaling

# %%
import pandas as pd

# Assuming df['age'] contains the age column
bins = [0, 18, 45, 65, 101]  # Age intervals
labels = ['Child', 'Adult', 'Middle-Aged Adult', 'Senior Adult']

df['age_group'] = pd.cut(df['age'], bins=bins, labels=labels, right=False)

print(df[['age', 'age_group']].head())  # Displaying the new age group column
# Out:
#     age          age_group
# 0  75.0       Senior Adult
# 1  55.0  Middle-Aged Adult
# 2  65.0       Senior Adult
# 3  50.0  Middle-Aged Adult
# 4  65.0       Senior Adult

# %%
from sklearn.preprocessing import StandardScaler

# Continuous features that require scaling
features_to_scale = ['age','creatinine_phosphokinase', 'ejection_fraction', 'platelets',
                     'serum_creatinine', 'serum_sodium', 'time']

# Applying StandardScaler
scaler = StandardScaler()
x_train[features_to_scale] = scaler.fit_transform(x_train[features_to_scale])
x_test[features_to_scale] = scaler.transform(x_test[features_to_scale])

print(x_train.head())
# Out:
#           age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 14  -1.001659        1                 -0.475559         0          -0.690159
# 210  0.734629        0                 -0.353834         1          -1.777468
# 236  1.148031        0                 -0.439595         0           0.982625
# 44  -0.092175        1                 -0.007104         1           1.819017
# 163 -0.918978        1                  1.602981         1          -0.271963
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 14                     1   1.751802         -0.577716      0.337912    0
# 210                    1   1.352637         -0.577716     -0.140892    1
# 236                    1  -0.128478         -0.353911      2.731935    1
# 44                     0  -0.695713         -0.353911      1.295522    0
# 163                    0  -1.945732         -0.801520      1.295522    0
#
#      smoking      time
# 14         0 -1.514594
# ...

# %% [markdown]
# ##feature importance

# %%
plt.figure(figsize=(10, 8))
corr_matrix = x_train.corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier
import pandas as pd

model = RandomForestClassifier()
model.fit(x_train, y_train)

# Get feature importances
feature_importances = pd.Series(model.feature_importances_, index=x_train.columns)
feature_importances = feature_importances.sort_values(ascending=False)
print(feature_importances)
# Out:
# time                        0.361059
# serum_creatinine            0.132995
# ejection_fraction           0.107199
# platelets                   0.089066
# serum_sodium                0.085988
# age                         0.083637
# creatinine_phosphokinase    0.079162
# anaemia                     0.016910
# sex                         0.015368
# smoking                     0.011455
# high_blood_pressure         0.008950
# diabetes                    0.008209
# dtype: float64

# %%
plt.figure(figsize=(10, 8))
# sns.heatmap(x_train.corr(), annot=True, cmap='coolwarm')
# plt.title('Correlation Heatmap')
# plt.show()
sns.kdeplot(x_train['age'])
sns.kdeplot(x_train['anaemia'])
sns.kdeplot(x_train['creatinine_phosphokinase'])
sns.kdeplot(x_train['diabetes'])
sns.kdeplot(x_train['ejection_fraction'])
sns.kdeplot(x_train['high_blood_pressure'])
sns.kdeplot(x_train['platelets'])
sns.kdeplot(x_train['serum_creatinine'])
sns.kdeplot(x_train['serum_sodium'])
sns.kdeplot(x_train['sex'])
sns.kdeplot(x_train['smoking'])
sns.kdeplot(x_train['time'])
# sns.kdeplot(x_train['DEATH_EVENT'])
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %% [markdown]
# #Data spliting for training and testing

# %%
x_train, x_test, y_train, y_test = train_test_split(
    x.drop(['anaemia', 'smoking', 'sex', 'high_blood_pressure', 'diabetes'], axis=1),
    y,
    test_size=0.3,
    random_state=1
)

# %% [markdown]
# #logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import PolynomialFeatures
# from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
ploy=PolynomialFeatures(degree=4)
x_train_p=ploy.fit_transform(x_train)
x_test_p=ploy.fit_transform(x_test)

# %%
lr1 = LogisticRegression()
lr1.fit(x_train_p, y_train)
print(f'Train: {lr1.score(x_train_p, y_train)}')
print(f'Test: {lr1.score(x_test_p, y_test)}')
# Out:
# Train: 0.8181818181818182
# Test: 0.8666666666666667
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# #Knn

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier()
param_grid_knn = {
    'n_neighbors': [3, 5, 7, 9, 11,20,30],
    'weights': ['uniform', 'distance'],
    'p': [1, 2,3,4]
}

grid_knn = GridSearchCV(knn, param_grid_knn, cv=5, scoring='accuracy')
grid_knn.fit(x_train, y_train)

print("Best parameters for KNN:", grid_knn.best_params_)
# Out:
# Best parameters for KNN: {'n_neighbors': 30, 'p': 1, 'weights': 'uniform'}

# %%
knn = KNeighborsClassifier(n_neighbors=30,p=1, weights='uniform')
knn.fit(x_train, y_train)
print(f'Train: {knn.score(x_train, y_train)}')
print(f'Test: {knn.score(x_test, y_test)}')
# Out:
# Train: 0.6650717703349283
# Test: 0.7111111111111111

# %% [markdown]
# #Decision tree

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Set the parameters for Decision Tree
tree = DecisionTreeClassifier()
param_grid_tree = {
    'max_depth': [3, 5, 7, 10],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'criterion': ['gini', 'entropy']
}

# Perform GridSearchCV for Decision Tree
grid_tree = GridSearchCV(tree, param_grid_tree, cv=10, scoring='accuracy')
grid_tree.fit(x_train, y_train)

# Print the best parameters and score
print("Best parameters for Decision Tree:", grid_tree.best_params_)
print("Best score for Decision Tree:", grid_tree.best_score_)
# Out:
# Best parameters for Decision Tree: {'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 2, 'min_samples_split': 10}
# Best score for Decision Tree: 0.8373809523809523

# %%
dt = DecisionTreeClassifier(criterion='gini', max_depth=7, min_samples_split=10, min_samples_leaf=2)
dt.fit(x_train, y_train)
print(f'Train: {dt.score(x_train, y_train)}')
print(f'Test: {dt.score(x_test, y_test)}')
# Out:
# Train: 0.9186602870813397
# Test: 0.8666666666666667

# %% [markdown]
# #Accuracy, precision, recall, f1_score

# %%
dt_pred = dt.predict(x_test)
dt_accuracy = accuracy_score(y_test, dt_pred)
dt_precision = precision_score(y_test, dt_pred)
dt_recall = recall_score(y_test, dt_pred)
dt_f1 = f1_score(y_test, dt_pred)


lr1_pred = lr1.predict(x_test_p)
lr1_accuracy = accuracy_score(y_test, lr1_pred)
lr1_precision = precision_score(y_test, lr1_pred)
lr1_recall = recall_score(y_test, lr1_pred)
lr1_f1 = f1_score(y_test, lr1_pred)

knn_pred = knn.predict(x_test)
knn_accuracy = accuracy_score(y_test, knn_pred)
knn_precision = precision_score(y_test, knn_pred)
knn_recall = recall_score(y_test, knn_pred)
knn_f1 = f1_score(y_test, knn_pred)

print(f'KNN Accuracy: {knn_accuracy}')
print(f'KNN Precision: {knn_precision}')
print(f'KNN Recall: {knn_recall}')
print(f'KNN F1 Score: {knn_f1}\n\n')

print(f'Logistic Regression Accuracy: {lr1_accuracy}')
print(f'Logistic Regression Precision: {lr1_precision}')
print(f'Logistic Regression Recall: {lr1_recall}')
print(f'Logistic Regression F1 Score: {lr1_f1}\n\n')

print(f'Decision tree Accuracy: {dt_accuracy}')
print(f'Decision tree Precision: {dt_precision}')
print(f'Decision tree Recall: {dt_recall}')
print(f'Decision tree F1 Score: {dt_f1}')
# Out:
# KNN Accuracy: 0.7111111111111111
# KNN Precision: 0.0
# KNN Recall: 0.0
# KNN F1 Score: 0.0
#
#
# Logistic Regression Accuracy: 0.8666666666666667
# Logistic Regression Precision: 0.9375
# Logistic Regression Recall: 0.5769230769230769
# Logistic Regression F1 Score: 0.7142857142857143
#
#
# Decision tree Accuracy: 0.8666666666666667
# Decision tree Precision: 0.9375
# Decision tree Recall: 0.5769230769230769
# Decision tree F1 Score: 0.7142857142857143
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
